# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime, date
import os
import os, glob

# %% [markdown]
# ## define drought extraction function

# %%
def drough_extract(id, th_type, moving_window, thresh_value, min_dur, path_id, path_out):
# def drough_extract(id, th_type, moving_window, thresh_value, min_dur, path_id, path_out, areakm2):    
    
    # area=float(areakm2)*(1000000)
    moving_window=moving_window
    thresh_value=thresh_value
    min_dur=min_dur

  ###  load df
    df = pd.read_csv(path_id)

  ### convert date to posixct format
    df['Datetime']=pd.to_datetime(df['Datetime'], format="%Y-%m-%d")

  ### extract date details
    df["day"] = df['Datetime'].map(lambda x: x.day)
    df["month"] = df['Datetime'].map(lambda x: x.month)
    df["year"] = df['Datetime'].map(lambda x: x.year)

  ### remove 29.02
    drop=list(df[(df['day'] ==29) & (df['month'] ==2)].index)
    df=df.drop(drop)
    df=df.reset_index(drop=True)

  ### convert discharge to mm/d
    # df['streamflow(mm/d)']=(df['streamflow']*86400)/area*1000
    ts=df['streamflow(mm/d)']
    
    ma_ts=ts.rolling(moving_window, min_periods=1, center=True).mean()

  #### fixed
    if th_type == 'fixed':
        thr = np.nanquantile(df['streamflow(mm/d)'],thresh_value)
        thr=np.full(365, thr)
  ### in case of a zero threshold, slightly elevate the threshold
        if thr[0]==0:
            thr=thr.np.full(0.01,365)
        else:
            thr=np.full(365, thr)
    converter= lambda x: x.timetuple().tm_yday
    if th_type == 'variable':
        if (len(df.year))==len(df ['year'])*365: 
            df['day_id']==np.tile( np.arange(0,365),(len(df.year.unique())))
        else:
            df['day_id']=df['Datetime'].map(converter)

        thr=[]
        for d in range(0,365):
        ### define window length
            win_length=np.arange(0,15) 
            before = list(df.day_id[d+365-win_length])
            after = list(df.day_id[d+365+win_length-1])
            ### define days within window
            ids_win = before+after
            ### determine values in window around day i
            data_window = ma_ts[df[df['day_id'].isin(ids_win)].index]
            quant_value = np.nanquantile(data_window,thresh_value)
            thr.append(quant_value)
            
    ### create column in table with corresponding thresholds
    df['threshold']=np.tile(thr,len(df.year.unique()))[:df.shape[0]]

    ### idetify events below threshold
    deficit_ids=np.where(ma_ts < df['threshold'])[0].tolist()
    deficit_datetime=df[df.index.isin(np.where(ma_ts < df['threshold'])[0].tolist())].Datetime
    end=np.where(np.array([x - deficit_ids[i - 1] for i, x in enumerate(deficit_ids)][1:]) >1)[0]
    start=end+1
    start=np.insert(start, 0,0)
    end=np.insert(end,len(end),(len(deficit_ids)-1))
    start_ids=[deficit_ids[index] for index in start]
    end_ids=[deficit_ids[index] for index in end]

   
    duration = []
    deficit = []
    intensity = []
    start_date = []
    end_date = []
    date = []
    thresh_events = []
    
    for e in range(len(start_ids)):
        duration.append(end[e] - start[e])
        deficit.append(abs(sum(ma_ts[start_ids[e]:(end_ids[e]+1)]-df.threshold[start_ids[e]:(end_ids[e]+1)])))
        intensity.append(min(ma_ts[start_ids[e]:(end_ids[e]+1)]))
        start_date.append(df.Datetime[start_ids[e]])
        end_date.append(df.Datetime[end_ids[e]])
        date.append(df[start_ids[e]:(end_ids[e]+1)].loc[ma_ts[start_ids[e]:(end_ids[e]+1)].idxmin()].Datetime)
        thresh_events.append(df[start_ids[e]:(end_ids[e]+1)].loc[ma_ts[start_ids[e]:(end_ids[e]+1)].idxmin()].threshold)

    event_df=pd.DataFrame(
        {'start_date':start_date,
        'end_date':end_date,
        'date':date,
        'thresh_events':thresh_events,
         'duration': duration, #days
        'deficit': deficit, #mm
        'intensity': intensity, #mm/day
        })
  ### remove events shorter than the minimum duration
    if len(np.where(event_df.duration<min_dur)[0].tolist()) >0:
        event_df=event_df.drop(np.where(event_df.duration<min_dur)[0].tolist(),axis=0) 
  
    path_to_save=os.path.join(path_out,"Cabra_"+str(id)+'_th'+str(thresh_value)+'_mw'+str(moving_window)+'_md'+str(min_dur))
    event_df.to_csv(path_to_save+".csv", sep=',',index=False)

# %% [markdown]
# ## load data and apply

# %%
##Load data
path_id = os.listdir('C:/Users/User/Downloads/Cabra/Data/database_mm/')
path_out= 'C:/Users/User/Downloads/Cabra/Drought/Q20_20mw'
path_att = pd.read_csv(f'C:/Users/User/Downloads/Cabra/CABra_attibutes_att.csv', sep=',', index_col= 'id')

# %%
# drough_extract(id, th_type, moving_window, thresh_value, min_dur, path_id, path_out):

for i in path_id:
    id=int(i.split("_")[1])
    path=os.path.join('C:/Users/User/Downloads/Cabra/Data/database_mm/',i)
    zeros= path_att.loc[{id},'% of zeros']
    if float(zeros)<=0.05:
        drough_extract(id, 'variable', 20, 0.20, 30, path, path_out)
        print("feito com sucesso:",i)
    else:
        print(i, "is ephemeral")
# Out:
# feito com sucesso: CABra_100_mmd.csv
# feito com sucesso: CABra_101_mmd.csv
# feito com sucesso: CABra_102_mmd.csv
# feito com sucesso: CABra_105_mmd.csv
# feito com sucesso: CABra_106_mmd.csv
# feito com sucesso: CABra_107_mmd.csv
# feito com sucesso: CABra_108_mmd.csv
# feito com sucesso: CABra_109_mmd.csv
# feito com sucesso: CABra_10_mmd.csv
# feito com sucesso: CABra_110_mmd.csv
# feito com sucesso: CABra_111_mmd.csv
# feito com sucesso: CABra_112_mmd.csv
# feito com sucesso: CABra_113_mmd.csv
# feito com sucesso: CABra_114_mmd.csv
# feito com sucesso: CABra_115_mmd.csv
# feito com sucesso: CABra_116_mmd.csv
# feito com sucesso: CABra_117_mmd.csv
# feito com sucesso: CABra_118_mmd.csv
# feito com sucesso: CABra_119_mmd.csv
# feito com sucesso: CABra_11_mmd.csv
# feito com sucesso: CABra_122_mmd.csv
# feito com sucesso: CABra_123_mmd.csv
# feito com sucesso: CABra_124_mmd.csv
# feito com sucesso: CABra_125_mmd.csv
# feito com sucesso: CABra_126_mmd.csv
# feito com sucesso: CABra_127_mmd.csv
# feito com sucesso: CABra_128_mmd.csv
# feito com sucesso: CABra_129_mmd.csv
# feito com sucesso: CABra_12_mmd.csv
# feito com sucesso: CABra_130_mmd.csv
# CABra_131_mmd.csv is ephemeral
# CABra_132_mmd.csv is ephemeral
# CABra_133_mmd.csv is ephemeral
# CABra_134_mmd.csv is ephemeral
# CABra_135_mmd.csv is ephemeral
# CABra_136_mmd.csv is ephemeral
# CABra_137_mmd.csv is ephemeral
# feito com sucesso: CABra_138_mmd.csv
# CABra_139_mmd.csv is ephemeral
# feito com sucesso: CABra_13_mmd.csv
# feito com sucesso: CABra_140_mmd.csv
# feito com sucesso: CABra_141_mmd.csv
# CABra_142_mmd.csv is ephemeral
# CABra_143_mmd.csv is ephemeral
# CABra_144_mmd.csv is ephemeral
# CABra_145_mmd.csv is ephemeral
# CABra_146_mmd.csv is ephemeral
# CABra_147_mmd.csv is ephemeral
# CABra_148_mmd.csv is ephemeral
# CABra_149_mmd.csv is ephemeral
# feito com sucesso: CABra_14_mmd.csv
# feito com sucesso: CABra_150_mmd.csv
# CABra_151_mmd.csv is ephemeral
# feito com sucesso: CABra_153_mmd.csv
# CABra_154_mmd.csv is ephemeral
# feito com sucesso: CABra_155_mmd.csv
# feito com sucesso: CABra_156_mmd.csv
# feito com sucesso: CABra_157_mmd.csv
# feito com sucesso: CABra_159_mmd.csv
# feito com sucesso: CABra_160_mmd.csv
# feito com sucesso: CABra_161_mmd.csv
# feito com sucesso: CABra_162_mmd.csv
# feito com sucesso: CABra_163_mmd.csv
# feito com sucesso: CABra_164_mmd.csv
# feito com sucesso: CABra_165_mmd.csv
# feito com sucesso: CABra_166_mmd.csv
# feito com sucesso: CABra_167_mmd.csv
# feito com sucesso: CABra_168_mmd.csv
# feito com sucesso: CABra_169_mmd.csv
# feito com sucesso: CABra_16_mmd.csv
# feito com sucesso: CABra_170_mmd.csv
# feito com sucesso: CABra_171_mmd.csv
# feito com sucesso: CABra_172_mmd.csv
# feito com sucesso: CABra_173_mmd.csv
# feito com sucesso: CABra_174_mmd.csv
# feito com sucesso: CABra_176_mmd.csv
# feito com sucesso: CABra_177_mmd.csv
# feito com sucesso: CABra_178_mmd.csv
# feito com sucesso: CABra_17_mmd.csv
# feito com sucesso: CABra_180_mmd.csv
# feito com sucesso: CABra_181_mmd.csv
# feito com sucesso: CABra_184_mmd.csv
# feito com sucesso: CABra_186_mmd.csv
# feito com sucesso: CABra_187_mmd.csv
# feito com sucesso: CABra_188_mmd.csv
# feito com sucesso: CABra_189_mmd.csv
# feito com sucesso: CABra_18_mmd.csv
# feito com sucesso: CABra_190_mmd.csv
# feito com sucesso: CABra_192_mmd.csv
# feito com sucesso: CABra_193_mmd.csv
# feito com sucesso: CABra_194_mmd.csv
# feito com sucesso: CABra_195_mmd.csv
# feito com sucesso: CABra_196_mmd.csv
# feito com sucesso: CABra_197_mmd.csv
# feito com sucesso: CABra_198_mmd.csv
# feito com sucesso: CABra_199_mmd.csv
# feito com sucesso: CABra_1_mmd.csv
# feito com sucesso: CABra_200_mmd.csv
# feito com sucesso: CABra_201_mmd.csv
# feito com sucesso: CABra_202_mmd.csv
# CABra_203_mmd.csv is ephemeral
# feito com sucesso: CABra_204_mmd.csv
# CABra_206_mmd.csv is ephemeral
# CABra_207_mmd.csv is ephemeral
# feito com sucesso: CABra_208_mmd.csv
# feito com sucesso: CABra_209_mmd.csv
# feito com sucesso: CABra_20_mmd.csv
# feito com sucesso: CABra_211_mmd.csv
# feito com sucesso: CABra_215_mmd.csv
# feito com sucesso: CABra_216_mmd.csv
# feito com sucesso: CABra_217_mmd.csv
# feito com sucesso: CABra_218_mmd.csv
# feito com sucesso: CABra_219_mmd.csv
# feito com sucesso: CABra_220_mmd.csv
# feito com sucesso: CABra_221_mmd.csv
# feito com sucesso: CABra_222_mmd.csv
# CABra_224_mmd.csv is ephemeral
# feito com sucesso: CABra_225_mmd.csv
# feito com sucesso: CABra_226_mmd.csv
# feito com sucesso: CABra_227_mmd.csv
# feito com sucesso: CABra_228_mmd.csv
# feito com sucesso: CABra_229_mmd.csv
# feito com sucesso: CABra_230_mmd.csv
# feito com sucesso: CABra_231_mmd.csv
# feito com sucesso: CABra_232_mmd.csv
# feito com sucesso: CABra_233_mmd.csv
# feito com sucesso: CABra_235_mmd.csv
# feito com sucesso: CABra_238_mmd.csv
# feito com sucesso: CABra_23_mmd.csv
# feito com sucesso: CABra_240_mmd.csv
# feito com sucesso: CABra_241_mmd.csv
# feito com sucesso: CABra_243_mmd.csv
# feito com sucesso: CABra_244_mmd.csv
# feito com sucesso: CABra_246_mmd.csv
# feito com sucesso: CABra_247_mmd.csv
# feito com sucesso: CABra_249_mmd.csv
# feito com sucesso: CABra_24_mmd.csv
# feito com sucesso: CABra_250_mmd.csv
# feito com sucesso: CABra_251_mmd.csv
# feito com sucesso: CABra_252_mmd.csv
# feito com sucesso: CABra_253_mmd.csv
# feito com sucesso: CABra_254_mmd.csv
# feito com sucesso: CABra_255_mmd.csv
# feito com sucesso: CABra_257_mmd.csv
# feito com sucesso: CABra_258_mmd.csv
# feito com sucesso: CABra_259_mmd.csv
# feito com sucesso: CABra_25_mmd.csv
# feito com sucesso: CABra_261_mmd.csv
# feito com sucesso: CABra_262_mmd.csv
# feito com sucesso: CABra_263_mmd.csv
# feito com sucesso: CABra_264_mmd.csv
# feito com sucesso: CABra_265_mmd.csv
# feito com sucesso: CABra_266_mmd.csv
# feito com sucesso: CABra_267_mmd.csv
# feito com sucesso: CABra_268_mmd.csv
# feito com sucesso: CABra_269_mmd.csv
# feito com sucesso: CABra_26_mmd.csv
# feito com sucesso: CABra_271_mmd.csv
# feito com sucesso: CABra_272_mmd.csv
# feito com sucesso: CABra_273_mmd.csv
# feito com sucesso: CABra_274_mmd.csv
# feito com sucesso: CABra_275_mmd.csv
# feito com sucesso: CABra_276_mmd.csv
# feito com sucesso: CABra_277_mmd.csv
# feito com sucesso: CABra_278_mmd.csv
# feito com sucesso: CABra_27_mmd.csv
# feito com sucesso: CABra_280_mmd.csv
# feito com sucesso: CABra_281_mmd.csv
# feito com sucesso: CABra_282_mmd.csv
# feito com sucesso: CABra_283_mmd.csv
# feito com sucesso: CABra_284_mmd.csv
# feito com sucesso: CABra_285_mmd.csv
# feito com sucesso: CABra_286_mmd.csv
# feito com sucesso: CABra_288_mmd.csv
# feito com sucesso: CABra_289_mmd.csv
# feito com sucesso: CABra_28_mmd.csv
# feito com sucesso: CABra_290_mmd.csv
# feito com sucesso: CABra_291_mmd.csv
# feito com sucesso: CABra_292_mmd.csv
# feito com sucesso: CABra_293_mmd.csv
# feito com sucesso: CABra_294_mmd.csv
# feito com sucesso: CABra_295_mmd.csv
# feito com sucesso: CABra_296_mmd.csv
# feito com sucesso: CABra_297_mmd.csv
# feito com sucesso: CABra_298_mmd.csv
# feito com sucesso: CABra_299_mmd.csv
# feito com sucesso: CABra_29_mmd.csv
# feito com sucesso: CABra_300_mmd.csv
# feito com sucesso: CABra_301_mmd.csv
# feito com sucesso: CABra_302_mmd.csv
# feito com sucesso: CABra_303_mmd.csv
# feito com sucesso: CABra_304_mmd.csv
# feito com sucesso: CABra_306_mmd.csv
# feito com sucesso: CABra_307_mmd.csv
# feito com sucesso: CABra_308_mmd.csv
# feito com sucesso: CABra_309_mmd.csv
# feito com sucesso: CABra_30_mmd.csv
# feito com sucesso: CABra_310_mmd.csv
# feito com sucesso: CABra_311_mmd.csv
# feito com sucesso: CABra_312_mmd.csv
# feito com sucesso: CABra_313_mmd.csv
# feito com sucesso: CABra_314_mmd.csv
# feito com sucesso: CABra_315_mmd.csv
# feito com sucesso: CABra_316_mmd.csv
# feito com sucesso: CABra_317_mmd.csv
# feito com sucesso: CABra_318_mmd.csv
# feito com sucesso: CABra_319_mmd.csv
# feito com sucesso: CABra_31_mmd.csv
# feito com sucesso: CABra_320_mmd.csv
# feito com sucesso: CABra_321_mmd.csv
# feito com sucesso: CABra_324_mmd.csv
# feito com sucesso: CABra_325_mmd.csv
# feito com sucesso: CABra_326_mmd.csv
# feito com sucesso: CABra_327_mmd.csv
# feito com sucesso: CABra_328_mmd.csv
# feito com sucesso: CABra_32_mmd.csv
# feito com sucesso: CABra_330_mmd.csv
# feito com sucesso: CABra_331_mmd.csv
# feito com sucesso: CABra_333_mmd.csv
# feito com sucesso: CABra_334_mmd.csv
# feito com sucesso: CABra_335_mmd.csv
# feito com sucesso: CABra_336_mmd.csv
# feito com sucesso: CABra_337_mmd.csv
# feito com sucesso: CABra_339_mmd.csv
# feito com sucesso: CABra_342_mmd.csv
# feito com sucesso: CABra_343_mmd.csv
# feito com sucesso: CABra_344_mmd.csv
# feito com sucesso: CABra_345_mmd.csv
# feito com sucesso: CABra_347_mmd.csv
# feito com sucesso: CABra_349_mmd.csv
# feito com sucesso: CABra_34_mmd.csv
# feito com sucesso: CABra_350_mmd.csv
# feito com sucesso: CABra_351_mmd.csv
# feito com sucesso: CABra_352_mmd.csv
# feito com sucesso: CABra_353_mmd.csv
# feito com sucesso: CABra_354_mmd.csv
# feito com sucesso: CABra_355_mmd.csv
# feito com sucesso: CABra_356_mmd.csv
# feito com sucesso: CABra_357_mmd.csv
# feito com sucesso: CABra_358_mmd.csv
# feito com sucesso: CABra_359_mmd.csv
# feito com sucesso: CABra_35_mmd.csv
# feito com sucesso: CABra_360_mmd.csv
# feito com sucesso: CABra_361_mmd.csv
# feito com sucesso: CABra_363_mmd.csv
# feito com sucesso: CABra_364_mmd.csv
# feito com sucesso: CABra_365_mmd.csv
# feito com sucesso: CABra_367_mmd.csv
# feito com sucesso: CABra_369_mmd.csv
# feito com sucesso: CABra_36_mmd.csv
# feito com sucesso: CABra_370_mmd.csv
# feito com sucesso: CABra_371_mmd.csv
# feito com sucesso: CABra_373_mmd.csv
# feito com sucesso: CABra_374_mmd.csv
# feito com sucesso: CABra_375_mmd.csv
# feito com sucesso: CABra_376_mmd.csv
# feito com sucesso: CABra_377_mmd.csv
# feito com sucesso: CABra_37_mmd.csv
# feito com sucesso: CABra_380_mmd.csv
# feito com sucesso: CABra_381_mmd.csv
# feito com sucesso: CABra_382_mmd.csv
# feito com sucesso: CABra_383_mmd.csv
# feito com sucesso: CABra_384_mmd.csv
# feito com sucesso: CABra_385_mmd.csv
# feito com sucesso: CABra_386_mmd.csv
# feito com sucesso: CABra_387_mmd.csv
# feito com sucesso: CABra_389_mmd.csv
# feito com sucesso: CABra_38_mmd.csv
# feito com sucesso: CABra_391_mmd.csv
# feito com sucesso: CABra_393_mmd.csv
# feito com sucesso: CABra_395_mmd.csv
# feito com sucesso: CABra_397_mmd.csv
# feito com sucesso: CABra_398_mmd.csv
# feito com sucesso: CABra_399_mmd.csv
# feito com sucesso: CABra_3_mmd.csv
# feito com sucesso: CABra_400_mmd.csv
# feito com sucesso: CABra_401_mmd.csv
# feito com sucesso: CABra_402_mmd.csv
# feito com sucesso: CABra_403_mmd.csv
# feito com sucesso: CABra_404_mmd.csv
# feito com sucesso: CABra_405_mmd.csv
# feito com sucesso: CABra_407_mmd.csv
# feito com sucesso: CABra_409_mmd.csv
# feito com sucesso: CABra_40_mmd.csv
# feito com sucesso: CABra_410_mmd.csv
# feito com sucesso: CABra_411_mmd.csv
# feito com sucesso: CABra_412_mmd.csv
# feito com sucesso: CABra_414_mmd.csv
# feito com sucesso: CABra_415_mmd.csv
# feito com sucesso: CABra_416_mmd.csv
# feito com sucesso: CABra_417_mmd.csv
# feito com sucesso: CABra_418_mmd.csv
# feito com sucesso: CABra_419_mmd.csv
# feito com sucesso: CABra_41_mmd.csv
# feito com sucesso: CABra_42_mmd.csv
# feito com sucesso: CABra_438_mmd.csv
# feito com sucesso: CABra_43_mmd.csv
# feito com sucesso: CABra_44_mmd.csv
# feito com sucesso: CABra_450_mmd.csv
# feito com sucesso: CABra_451_mmd.csv
# feito com sucesso: CABra_452_mmd.csv
# feito com sucesso: CABra_453_mmd.csv
# feito com sucesso: CABra_455_mmd.csv
# feito com sucesso: CABra_456_mmd.csv
# feito com sucesso: CABra_457_mmd.csv
# feito com sucesso: CABra_458_mmd.csv
# feito com sucesso: CABra_45_mmd.csv
# feito com sucesso: CABra_460_mmd.csv
# feito com sucesso: CABra_461_mmd.csv
# feito com sucesso: CABra_462_mmd.csv
# feito com sucesso: CABra_463_mmd.csv
# feito com sucesso: CABra_464_mmd.csv
# feito com sucesso: CABra_465_mmd.csv
# feito com sucesso: CABra_466_mmd.csv
# feito com sucesso: CABra_467_mmd.csv
# feito com sucesso: CABra_470_mmd.csv
# feito com sucesso: CABra_471_mmd.csv
# feito com sucesso: CABra_472_mmd.csv
# feito com sucesso: CABra_473_mmd.csv
# feito com sucesso: CABra_474_mmd.csv
# feito com sucesso: CABra_475_mmd.csv
# feito com sucesso: CABra_477_mmd.csv
# feito com sucesso: CABra_479_mmd.csv
# feito com sucesso: CABra_47_mmd.csv
# feito com sucesso: CABra_480_mmd.csv
# feito com sucesso: CABra_483_mmd.csv
# feito com sucesso: CABra_486_mmd.csv
# feito com sucesso: CABra_487_mmd.csv
# feito com sucesso: CABra_488_mmd.csv
# feito com sucesso: CABra_489_mmd.csv
# feito com sucesso: CABra_48_mmd.csv
# feito com sucesso: CABra_490_mmd.csv
# feito com sucesso: CABra_491_mmd.csv
# feito com sucesso: CABra_493_mmd.csv
# feito com sucesso: CABra_495_mmd.csv
# feito com sucesso: CABra_496_mmd.csv
# feito com sucesso: CABra_499_mmd.csv
# feito com sucesso: CABra_49_mmd.csv
# feito com sucesso: CABra_4_mmd.csv
# feito com sucesso: CABra_500_mmd.csv
# feito com sucesso: CABra_501_mmd.csv
# feito com sucesso: CABra_502_mmd.csv
# feito com sucesso: CABra_503_mmd.csv
# feito com sucesso: CABra_504_mmd.csv
# feito com sucesso: CABra_506_mmd.csv
# feito com sucesso: CABra_507_mmd.csv
# feito com sucesso: CABra_509_mmd.csv
# feito com sucesso: CABra_510_mmd.csv
# feito com sucesso: CABra_511_mmd.csv
# feito com sucesso: CABra_515_mmd.csv
# feito com sucesso: CABra_520_mmd.csv
# feito com sucesso: CABra_521_mmd.csv
# feito com sucesso: CABra_522_mmd.csv
# feito com sucesso: CABra_526_mmd.csv
# feito com sucesso: CABra_527_mmd.csv
# feito com sucesso: CABra_528_mmd.csv
# feito com sucesso: CABra_529_mmd.csv
# feito com sucesso: CABra_530_mmd.csv
# feito com sucesso: CABra_531_mmd.csv
# feito com sucesso: CABra_532_mmd.csv
# feito com sucesso: CABra_533_mmd.csv
# feito com sucesso: CABra_535_mmd.csv
# feito com sucesso: CABra_537_mmd.csv
# feito com sucesso: CABra_538_mmd.csv
# feito com sucesso: CABra_539_mmd.csv
# feito com sucesso: CABra_540_mmd.csv
# feito com sucesso: CABra_541_mmd.csv
# feito com sucesso: CABra_543_mmd.csv
# feito com sucesso: CABra_545_mmd.csv
# feito com sucesso: CABra_546_mmd.csv
# feito com sucesso: CABra_547_mmd.csv
# feito com sucesso: CABra_548_mmd.csv
# feito com sucesso: CABra_549_mmd.csv
# feito com sucesso: CABra_552_mmd.csv
# feito com sucesso: CABra_553_mmd.csv
# feito com sucesso: CABra_554_mmd.csv
# feito com sucesso: CABra_555_mmd.csv
# feito com sucesso: CABra_556_mmd.csv
# feito com sucesso: CABra_557_mmd.csv
# feito com sucesso: CABra_558_mmd.csv
# feito com sucesso: CABra_559_mmd.csv
# feito com sucesso: CABra_55_mmd.csv
# feito com sucesso: CABra_560_mmd.csv
# feito com sucesso: CABra_561_mmd.csv
# feito com sucesso: CABra_562_mmd.csv
# feito com sucesso: CABra_563_mmd.csv
# feito com sucesso: CABra_564_mmd.csv
# feito com sucesso: CABra_565_mmd.csv
# feito com sucesso: CABra_566_mmd.csv
# feito com sucesso: CABra_567_mmd.csv
# feito com sucesso: CABra_568_mmd.csv
# feito com sucesso: CABra_569_mmd.csv
# feito com sucesso: CABra_570_mmd.csv
# feito com sucesso: CABra_572_mmd.csv
# feito com sucesso: CABra_574_mmd.csv
# feito com sucesso: CABra_575_mmd.csv
# feito com sucesso: CABra_577_mmd.csv
# feito com sucesso: CABra_578_mmd.csv
# feito com sucesso: CABra_579_mmd.csv
# feito com sucesso: CABra_580_mmd.csv
# feito com sucesso: CABra_581_mmd.csv
# feito com sucesso: CABra_582_mmd.csv
# feito com sucesso: CABra_583_mmd.csv
# feito com sucesso: CABra_584_mmd.csv
# feito com sucesso: CABra_585_mmd.csv
# feito com sucesso: CABra_587_mmd.csv
# feito com sucesso: CABra_588_mmd.csv
# feito com sucesso: CABra_589_mmd.csv
# feito com sucesso: CABra_590_mmd.csv
# feito com sucesso: CABra_591_mmd.csv
# feito com sucesso: CABra_592_mmd.csv
# feito com sucesso: CABra_593_mmd.csv
# feito com sucesso: CABra_594_mmd.csv
# feito com sucesso: CABra_595_mmd.csv
# feito com sucesso: CABra_596_mmd.csv
# feito com sucesso: CABra_597_mmd.csv
# feito com sucesso: CABra_598_mmd.csv
# feito com sucesso: CABra_599_mmd.csv
# feito com sucesso: CABra_59_mmd.csv
# feito com sucesso: CABra_5_mmd.csv
# feito com sucesso: CABra_600_mmd.csv
# feito com sucesso: CABra_601_mmd.csv
# feito com sucesso: CABra_602_mmd.csv
# feito com sucesso: CABra_603_mmd.csv
# feito com sucesso: CABra_604_mmd.csv
# feito com sucesso: CABra_605_mmd.csv
# feito com sucesso: CABra_606_mmd.csv
# feito com sucesso: CABra_607_mmd.csv
# feito com sucesso: CABra_608_mmd.csv
# feito com sucesso: CABra_609_mmd.csv
# feito com sucesso: CABra_60_mmd.csv
# feito com sucesso: CABra_611_mmd.csv
# feito com sucesso: CABra_612_mmd.csv
# feito com sucesso: CABra_613_mmd.csv
# feito com sucesso: CABra_614_mmd.csv
# feito com sucesso: CABra_616_mmd.csv
# feito com sucesso: CABra_617_mmd.csv
# feito com sucesso: CABra_618_mmd.csv
# feito com sucesso: CABra_619_mmd.csv
# feito com sucesso: CABra_61_mmd.csv
# feito com sucesso: CABra_620_mmd.csv
# feito com sucesso: CABra_621_mmd.csv
# feito com sucesso: CABra_622_mmd.csv
# feito com sucesso: CABra_623_mmd.csv
# feito com sucesso: CABra_625_mmd.csv
# feito com sucesso: CABra_627_mmd.csv
# feito com sucesso: CABra_628_mmd.csv
# feito com sucesso: CABra_631_mmd.csv
# feito com sucesso: CABra_632_mmd.csv
# feito com sucesso: CABra_633_mmd.csv
# feito com sucesso: CABra_636_mmd.csv
# feito com sucesso: CABra_638_mmd.csv
# feito com sucesso: CABra_639_mmd.csv
# feito com sucesso: CABra_640_mmd.csv
# feito com sucesso: CABra_641_mmd.csv
# feito com sucesso: CABra_644_mmd.csv
# feito com sucesso: CABra_645_mmd.csv
# feito com sucesso: CABra_646_mmd.csv
# feito com sucesso: CABra_648_mmd.csv
# feito com sucesso: CABra_649_mmd.csv
# feito com sucesso: CABra_650_mmd.csv
# feito com sucesso: CABra_651_mmd.csv
# feito com sucesso: CABra_652_mmd.csv
# feito com sucesso: CABra_654_mmd.csv
# feito com sucesso: CABra_655_mmd.csv
# feito com sucesso: CABra_656_mmd.csv
# feito com sucesso: CABra_657_mmd.csv
# feito com sucesso: CABra_658_mmd.csv
# feito com sucesso: CABra_659_mmd.csv
# feito com sucesso: CABra_660_mmd.csv
# feito com sucesso: CABra_661_mmd.csv
# feito com sucesso: CABra_662_mmd.csv
# feito com sucesso: CABra_663_mmd.csv
# feito com sucesso: CABra_665_mmd.csv
# feito com sucesso: CABra_66_mmd.csv
# feito com sucesso: CABra_670_mmd.csv
# feito com sucesso: CABra_674_mmd.csv
# feito com sucesso: CABra_67_mmd.csv
# feito com sucesso: CABra_680_mmd.csv
# feito com sucesso: CABra_681_mmd.csv
# feito com sucesso: CABra_683_mmd.csv
# feito com sucesso: CABra_684_mmd.csv
# feito com sucesso: CABra_685_mmd.csv
# CABra_688_mmd.csv is ephemeral
# feito com sucesso: CABra_689_mmd.csv
# feito com sucesso: CABra_68_mmd.csv
# feito com sucesso: CABra_692_mmd.csv
# feito com sucesso: CABra_694_mmd.csv
# feito com sucesso: CABra_696_mmd.csv
# feito com sucesso: CABra_699_mmd.csv
# feito com sucesso: CABra_6_mmd.csv
# feito com sucesso: CABra_700_mmd.csv
# feito com sucesso: CABra_704_mmd.csv
# feito com sucesso: CABra_706_mmd.csv
# feito com sucesso: CABra_707_mmd.csv
# feito com sucesso: CABra_70_mmd.csv
# feito com sucesso: CABra_710_mmd.csv
# feito com sucesso: CABra_711_mmd.csv
# feito com sucesso: CABra_712_mmd.csv
# feito com sucesso: CABra_714_mmd.csv
# feito com sucesso: CABra_715_mmd.csv
# feito com sucesso: CABra_71_mmd.csv
# feito com sucesso: CABra_720_mmd.csv
# feito com sucesso: CABra_723_mmd.csv
# feito com sucesso: CABra_725_mmd.csv
# feito com sucesso: CABra_726_mmd.csv
# feito com sucesso: CABra_727_mmd.csv
# feito com sucesso: CABra_728_mmd.csv
# feito com sucesso: CABra_729_mmd.csv
# feito com sucesso: CABra_72_mmd.csv
# feito com sucesso: CABra_731_mmd.csv
# feito com sucesso: CABra_733_mmd.csv
# feito com sucesso: CABra_734_mmd.csv
# feito com sucesso: CABra_74_mmd.csv
# feito com sucesso: CABra_75_mmd.csv
# feito com sucesso: CABra_76_mmd.csv
# feito com sucesso: CABra_77_mmd.csv
# feito com sucesso: CABra_7_mmd.csv
# feito com sucesso: CABra_80_mmd.csv
# feito com sucesso: CABra_81_mmd.csv
# feito com sucesso: CABra_82_mmd.csv
# feito com sucesso: CABra_85_mmd.csv
# feito com sucesso: CABra_86_mmd.csv
# feito com sucesso: CABra_87_mmd.csv
# feito com sucesso: CABra_8_mmd.csv
# feito com sucesso: CABra_90_mmd.csv
# feito com sucesso: CABra_92_mmd.csv
# feito com sucesso: CABra_93_mmd.csv
# feito com sucesso: CABra_95_mmd.csv
# feito com sucesso: CABra_96_mmd.csv
# feito com sucesso: CABra_97_mmd.csv
# feito com sucesso: CABra_98_mmd.csv
# feito com sucesso: CABra_99_mmd.csv
# feito com sucesso: CABra_9_mmd.csv
