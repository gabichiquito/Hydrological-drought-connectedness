# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime, date
import os
import os, glob

# %%
path = r'C:\path_to_data' ## Insert your directory
os.chdir(path)

# %% [markdown]
# # Define hydrological drought extraction function

# %%
def drough_extract(id, th_type, moving_window, thresh_value, min_dur, path_id, path_out):
# (th_type = threshold type, that can be fixed or variable; moving_window in number of days; thresh_value in flow percentile; min_dur in days)
# the streamflow values has to be in mm/day    

    moving_window=moving_window
    thresh_value=thresh_value
    min_dur=min_dur

  ###  load df
    df = pd.read_csv(path_id)

  ### convert date to posixct format
    df = df.dropna()
    df['Datetime']=pd.to_datetime(df['Datetime'], format="%Y-%m-%d", errors="coerce").fillna(
        pd.to_datetime(df['Datetime'], format= "%m/%d/%Y", errors="coerce"))

    

  ### extract date details
    df["day"] = df['Datetime'].map(lambda x: x.day)
    df["month"] = df['Datetime'].map(lambda x: x.month)
    df["year"] = df['Datetime'].map(lambda x: x.year)

  ### remove 29.02
    drop=list(df[(df['day'] ==29) & (df['month'] ==2)].index)
    df=df.drop(drop)
    df=df.reset_index(drop=True)

  ### Smooth time series
    ts=df['streamflow(mm/d)']
    
    ma_ts=ts.rolling(moving_window, min_periods=1, center=True).mean()

  #### fixed threshold
    if th_type == 'fixed':
        thr = np.nanquantile(df['streamflow(mm/d)'],thresh_value)
        thr=np.full(365, thr)
      ### in case of a zero threshold, slightly elevate the threshold
        if thr[0]==0:
            thr=thr.np.full(0.01,365)
        else:
            thr=np.full(365, thr)
    converter= lambda x: x.timetuple().tm_yday
    
 #### variable threshold   
    if th_type == 'variable':
        if (len(df.year))==len(df ['year'])*365: 
            df['day_id']==np.tile( np.arange(0,365),(len(df.year.unique())))
        else:
            df['day_id']=df['Datetime'].map(converter)

        thr=[]
        
        for d in range(0,365):
        ### define window length
            win_length=np.arange(0,15) 
            before = list(df.day_id[d+365-win_length])
            after = list(df.day_id[d+365+win_length-1])
            ### define days within window
            ids_win = before+after
            ### determine values in window around day i
            data_window = ma_ts[df[df['day_id'].isin(ids_win)].index]
            quant_value = np.nanquantile(data_window,thresh_value)
            thr.append(quant_value)
            
    ### create column in table with corresponding thresholds
    df['threshold']=np.tile(thr,len(df.year.unique()))[:df.shape[0]]

    ### idetify events below threshold
    deficit_ids=np.where(ma_ts < df['threshold'])[0].tolist()
    deficit_datetime=df[df.index.isin(np.where(ma_ts < df['threshold'])[0].tolist())].Datetime
    end=np.where(np.array([x - deficit_ids[i - 1] for i, x in enumerate(deficit_ids)][1:]) >1)[0]
    start=end+1
    start=np.insert(start, 0,0)
    end=np.insert(end,len(end),(len(deficit_ids)-1))
    start_ids=[deficit_ids[index] for index in start]
    end_ids=[deficit_ids[index] for index in end]

   ### compute drought characteristics
    duration = []
    deficit = []
    intensity = []
    start_date = []
    end_date = []
    date = []
    thresh_events = []
    
    for e in range(len(start_ids)):
        duration.append(end[e] - start[e])
        deficit.append(abs(sum(ma_ts[start_ids[e]:(end_ids[e]+1)]-df.threshold[start_ids[e]:(end_ids[e]+1)])))
        intensity.append(min(ma_ts[start_ids[e]:(end_ids[e]+1)]))
        start_date.append(df.Datetime[start_ids[e]])
        end_date.append(df.Datetime[end_ids[e]])
        date.append(df[start_ids[e]:(end_ids[e]+1)].loc[ma_ts[start_ids[e]:(end_ids[e]+1)].idxmin()].Datetime)
        thresh_events.append(df[start_ids[e]:(end_ids[e]+1)].loc[ma_ts[start_ids[e]:(end_ids[e]+1)].idxmin()].threshold)

    event_df=pd.DataFrame(
        {'start_date':start_date,
        'end_date':end_date,
        'date':date,
        'thresh_events':thresh_events,
         'duration': duration, #days
        'deficit': deficit, #mm
        'intensity': intensity, #mm/day
        })
  ### remove events shorter than the minimum duration
    if len(np.where(event_df.duration<min_dur)[0].tolist()) >0:
        event_df=event_df.drop(np.where(event_df.duration<min_dur)[0].tolist(),axis=0) 
        
  ### save files
    path_to_save=os.path.join(path_out,"Cabra_"+str(id)+'_th'+str(thresh_value)+'_mw'+str(moving_window)+'_md'+str(min_dur))
    event_df.to_csv(path_to_save+".csv", sep=',',index=False)

# %% [markdown]
# ## load data and apply

# %%
##Load data
path_id = os.listdir('database_mm/')
path_out= ''
path_att = pd.read_csv('CABra_attibutes.csv', sep=',', index_col= 'id')

# %%
for i in path_id:
    id=int(i.split("_")[1])
    path=os.path.join('database_mm/',i)
    zeros= np.count_nonzero(pd.read_csv(path)['streamflow(mm/d)']==0)
    if float(zeros)<=0.05:
        drough_extract(id, 'variable', 30, 0.15, 30, path, path_out)
        print("successfully done:",i)
    else:
        print(i, "is ephemeral")
# Out:
# successfully done: CABra_100_mmd.csv
# successfully done: CABra_101_mmd.csv
# successfully done: CABra_102_mmd.csv
# successfully done: CABra_105_mmd.csv
# successfully done: CABra_106_mmd.csv
# CABra_107_mmd.csv is ephemeral
# successfully done: CABra_108_mmd.csv
# CABra_109_mmd.csv is ephemeral
# successfully done: CABra_10_mmd.csv
# successfully done: CABra_110_mmd.csv
# successfully done: CABra_111_mmd.csv
# successfully done: CABra_112_mmd.csv
# successfully done: CABra_113_mmd.csv
# successfully done: CABra_114_mmd.csv
# successfully done: CABra_115_mmd.csv
# successfully done: CABra_116_mmd.csv
# successfully done: CABra_117_mmd.csv
# successfully done: CABra_118_mmd.csv
# successfully done: CABra_119_mmd.csv
# successfully done: CABra_11_mmd.csv
# successfully done: CABra_122_mmd.csv
# successfully done: CABra_123_mmd.csv
# successfully done: CABra_124_mmd.csv
# successfully done: CABra_125_mmd.csv
# successfully done: CABra_126_mmd.csv
# successfully done: CABra_127_mmd.csv
# CABra_128_mmd.csv is ephemeral
# CABra_129_mmd.csv is ephemeral
# successfully done: CABra_12_mmd.csv
# CABra_130_mmd.csv is ephemeral
# CABra_131_mmd.csv is ephemeral
# CABra_132_mmd.csv is ephemeral
# CABra_133_mmd.csv is ephemeral
# CABra_134_mmd.csv is ephemeral
# CABra_135_mmd.csv is ephemeral
# CABra_136_mmd.csv is ephemeral
# CABra_137_mmd.csv is ephemeral
# CABra_138_mmd.csv is ephemeral
# CABra_139_mmd.csv is ephemeral
# successfully done: CABra_13_mmd.csv
# CABra_140_mmd.csv is ephemeral
# CABra_141_mmd.csv is ephemeral
# CABra_142_mmd.csv is ephemeral
# CABra_143_mmd.csv is ephemeral
# CABra_144_mmd.csv is ephemeral
# CABra_145_mmd.csv is ephemeral
# CABra_146_mmd.csv is ephemeral
# CABra_147_mmd.csv is ephemeral
# CABra_148_mmd.csv is ephemeral
# CABra_149_mmd.csv is ephemeral
# successfully done: CABra_14_mmd.csv
# CABra_150_mmd.csv is ephemeral
# CABra_151_mmd.csv is ephemeral
# successfully done: CABra_153_mmd.csv
# CABra_154_mmd.csv is ephemeral
# successfully done: CABra_155_mmd.csv
# CABra_156_mmd.csv is ephemeral
# CABra_157_mmd.csv is ephemeral
# successfully done: CABra_159_mmd.csv
# successfully done: CABra_160_mmd.csv
# successfully done: CABra_161_mmd.csv
# successfully done: CABra_162_mmd.csv
# successfully done: CABra_163_mmd.csv
# successfully done: CABra_164_mmd.csv
# CABra_165_mmd.csv is ephemeral
# successfully done: CABra_166_mmd.csv
# successfully done: CABra_167_mmd.csv
# successfully done: CABra_168_mmd.csv
# successfully done: CABra_169_mmd.csv
# successfully done: CABra_16_mmd.csv
# CABra_170_mmd.csv is ephemeral
# successfully done: CABra_171_mmd.csv
# successfully done: CABra_172_mmd.csv
# successfully done: CABra_173_mmd.csv
# successfully done: CABra_174_mmd.csv
# CABra_176_mmd.csv is ephemeral
# successfully done: CABra_177_mmd.csv
# successfully done: CABra_178_mmd.csv
# successfully done: CABra_17_mmd.csv
# successfully done: CABra_180_mmd.csv
# successfully done: CABra_181_mmd.csv
# CABra_184_mmd.csv is ephemeral
# successfully done: CABra_186_mmd.csv
# successfully done: CABra_187_mmd.csv
# successfully done: CABra_188_mmd.csv
# successfully done: CABra_189_mmd.csv
# successfully done: CABra_18_mmd.csv
# successfully done: CABra_190_mmd.csv
# successfully done: CABra_192_mmd.csv
# successfully done: CABra_193_mmd.csv
# successfully done: CABra_194_mmd.csv
# successfully done: CABra_195_mmd.csv
# successfully done: CABra_196_mmd.csv
# successfully done: CABra_197_mmd.csv
# successfully done: CABra_198_mmd.csv
# successfully done: CABra_199_mmd.csv
# successfully done: CABra_1_mmd.csv
# successfully done: CABra_200_mmd.csv
# successfully done: CABra_201_mmd.csv
# CABra_202_mmd.csv is ephemeral
# CABra_203_mmd.csv is ephemeral
# CABra_204_mmd.csv is ephemeral
# CABra_206_mmd.csv is ephemeral
# CABra_207_mmd.csv is ephemeral
# CABra_208_mmd.csv is ephemeral
# successfully done: CABra_209_mmd.csv
# CABra_20_mmd.csv is ephemeral
# successfully done: CABra_211_mmd.csv
# successfully done: CABra_215_mmd.csv
# successfully done: CABra_216_mmd.csv
# CABra_217_mmd.csv is ephemeral
# successfully done: CABra_218_mmd.csv
# CABra_219_mmd.csv is ephemeral
# successfully done: CABra_220_mmd.csv
# successfully done: CABra_221_mmd.csv
# CABra_222_mmd.csv is ephemeral
# CABra_224_mmd.csv is ephemeral
# CABra_225_mmd.csv is ephemeral
# successfully done: CABra_226_mmd.csv
# successfully done: CABra_227_mmd.csv
# successfully done: CABra_228_mmd.csv
# successfully done: CABra_229_mmd.csv
# CABra_230_mmd.csv is ephemeral
# successfully done: CABra_231_mmd.csv
# successfully done: CABra_232_mmd.csv
# successfully done: CABra_233_mmd.csv
# successfully done: CABra_235_mmd.csv
# successfully done: CABra_238_mmd.csv
# successfully done: CABra_23_mmd.csv
# CABra_240_mmd.csv is ephemeral
# successfully done: CABra_241_mmd.csv
# successfully done: CABra_243_mmd.csv
# successfully done: CABra_244_mmd.csv
# successfully done: CABra_246_mmd.csv
# successfully done: CABra_247_mmd.csv
# successfully done: CABra_249_mmd.csv
# successfully done: CABra_24_mmd.csv
# successfully done: CABra_250_mmd.csv
# successfully done: CABra_251_mmd.csv
# successfully done: CABra_252_mmd.csv
# successfully done: CABra_253_mmd.csv
# successfully done: CABra_254_mmd.csv
# successfully done: CABra_255_mmd.csv
# CABra_257_mmd.csv is ephemeral
# successfully done: CABra_258_mmd.csv
# CABra_259_mmd.csv is ephemeral
# successfully done: CABra_25_mmd.csv
# successfully done: CABra_261_mmd.csv
# successfully done: CABra_262_mmd.csv
# successfully done: CABra_263_mmd.csv
# successfully done: CABra_264_mmd.csv
# successfully done: CABra_265_mmd.csv
# successfully done: CABra_266_mmd.csv
# successfully done: CABra_267_mmd.csv
# successfully done: CABra_268_mmd.csv
# successfully done: CABra_269_mmd.csv
# successfully done: CABra_26_mmd.csv
# successfully done: CABra_271_mmd.csv
# successfully done: CABra_272_mmd.csv
# successfully done: CABra_273_mmd.csv
# successfully done: CABra_274_mmd.csv
# successfully done: CABra_275_mmd.csv
# successfully done: CABra_276_mmd.csv
# successfully done: CABra_277_mmd.csv
# successfully done: CABra_278_mmd.csv
# successfully done: CABra_27_mmd.csv
# CABra_280_mmd.csv is ephemeral
# successfully done: CABra_281_mmd.csv
# successfully done: CABra_282_mmd.csv
# CABra_283_mmd.csv is ephemeral
# successfully done: CABra_284_mmd.csv
# successfully done: CABra_285_mmd.csv
# successfully done: CABra_286_mmd.csv
# successfully done: CABra_288_mmd.csv
# successfully done: CABra_289_mmd.csv
# successfully done: CABra_28_mmd.csv
# successfully done: CABra_290_mmd.csv
# successfully done: CABra_291_mmd.csv
# successfully done: CABra_292_mmd.csv
# CABra_293_mmd.csv is ephemeral
# CABra_294_mmd.csv is ephemeral
# successfully done: CABra_295_mmd.csv
# successfully done: CABra_296_mmd.csv
# successfully done: CABra_297_mmd.csv
# successfully done: CABra_298_mmd.csv
# successfully done: CABra_299_mmd.csv
# successfully done: CABra_29_mmd.csv
# successfully done: CABra_300_mmd.csv
# successfully done: CABra_301_mmd.csv
# successfully done: CABra_302_mmd.csv
# successfully done: CABra_303_mmd.csv
# successfully done: CABra_304_mmd.csv
# successfully done: CABra_306_mmd.csv
# successfully done: CABra_307_mmd.csv
# successfully done: CABra_308_mmd.csv
# CABra_309_mmd.csv is ephemeral
# successfully done: CABra_30_mmd.csv
# successfully done: CABra_310_mmd.csv
# successfully done: CABra_311_mmd.csv
# CABra_312_mmd.csv is ephemeral
# successfully done: CABra_313_mmd.csv
# successfully done: CABra_314_mmd.csv
# successfully done: CABra_315_mmd.csv
# successfully done: CABra_316_mmd.csv
# successfully done: CABra_317_mmd.csv
# successfully done: CABra_318_mmd.csv
# successfully done: CABra_319_mmd.csv
# successfully done: CABra_31_mmd.csv
# successfully done: CABra_320_mmd.csv
# successfully done: CABra_321_mmd.csv
# successfully done: CABra_324_mmd.csv
# successfully done: CABra_325_mmd.csv
# successfully done: CABra_326_mmd.csv
# successfully done: CABra_327_mmd.csv
# CABra_328_mmd.csv is ephemeral
# successfully done: CABra_32_mmd.csv
# successfully done: CABra_330_mmd.csv
# successfully done: CABra_331_mmd.csv
# successfully done: CABra_333_mmd.csv
# successfully done: CABra_334_mmd.csv
# successfully done: CABra_335_mmd.csv
# successfully done: CABra_336_mmd.csv
# successfully done: CABra_337_mmd.csv
# successfully done: CABra_339_mmd.csv
# successfully done: CABra_342_mmd.csv
# successfully done: CABra_343_mmd.csv
# successfully done: CABra_344_mmd.csv
# successfully done: CABra_345_mmd.csv
# successfully done: CABra_347_mmd.csv
# successfully done: CABra_349_mmd.csv
# successfully done: CABra_34_mmd.csv
# successfully done: CABra_350_mmd.csv
# successfully done: CABra_351_mmd.csv
# successfully done: CABra_352_mmd.csv
# successfully done: CABra_353_mmd.csv
# successfully done: CABra_354_mmd.csv
# successfully done: CABra_355_mmd.csv
# successfully done: CABra_356_mmd.csv
# successfully done: CABra_357_mmd.csv
# successfully done: CABra_358_mmd.csv
# successfully done: CABra_359_mmd.csv
# successfully done: CABra_35_mmd.csv
# successfully done: CABra_360_mmd.csv
# successfully done: CABra_361_mmd.csv
# successfully done: CABra_363_mmd.csv
# successfully done: CABra_364_mmd.csv
# successfully done: CABra_365_mmd.csv
# successfully done: CABra_367_mmd.csv
# successfully done: CABra_369_mmd.csv
# successfully done: CABra_36_mmd.csv
# successfully done: CABra_370_mmd.csv
# successfully done: CABra_371_mmd.csv
# successfully done: CABra_373_mmd.csv
# successfully done: CABra_374_mmd.csv
# successfully done: CABra_375_mmd.csv
# successfully done: CABra_376_mmd.csv
# successfully done: CABra_377_mmd.csv
# successfully done: CABra_37_mmd.csv
# successfully done: CABra_380_mmd.csv
# successfully done: CABra_381_mmd.csv
# successfully done: CABra_382_mmd.csv
# successfully done: CABra_383_mmd.csv
# successfully done: CABra_384_mmd.csv
# successfully done: CABra_385_mmd.csv
# successfully done: CABra_386_mmd.csv
# successfully done: CABra_387_mmd.csv
# successfully done: CABra_389_mmd.csv
# successfully done: CABra_38_mmd.csv
# successfully done: CABra_391_mmd.csv
# successfully done: CABra_393_mmd.csv
# successfully done: CABra_395_mmd.csv
# successfully done: CABra_397_mmd.csv
# successfully done: CABra_398_mmd.csv
# successfully done: CABra_399_mmd.csv
# successfully done: CABra_3_mmd.csv
# successfully done: CABra_400_mmd.csv
# successfully done: CABra_401_mmd.csv
# successfully done: CABra_402_mmd.csv
# successfully done: CABra_403_mmd.csv
# successfully done: CABra_404_mmd.csv
# successfully done: CABra_405_mmd.csv
# successfully done: CABra_407_mmd.csv
# successfully done: CABra_409_mmd.csv
# successfully done: CABra_40_mmd.csv
# successfully done: CABra_410_mmd.csv
# successfully done: CABra_411_mmd.csv
# successfully done: CABra_412_mmd.csv
# successfully done: CABra_414_mmd.csv
# successfully done: CABra_415_mmd.csv
# successfully done: CABra_416_mmd.csv
# successfully done: CABra_417_mmd.csv
# successfully done: CABra_418_mmd.csv
# successfully done: CABra_419_mmd.csv
# successfully done: CABra_41_mmd.csv
# successfully done: CABra_42_mmd.csv
# successfully done: CABra_438_mmd.csv
# successfully done: CABra_43_mmd.csv
# successfully done: CABra_44_mmd.csv
# successfully done: CABra_450_mmd.csv
# successfully done: CABra_451_mmd.csv
# successfully done: CABra_452_mmd.csv
# CABra_453_mmd.csv is ephemeral
# successfully done: CABra_455_mmd.csv
# successfully done: CABra_456_mmd.csv
# successfully done: CABra_457_mmd.csv
# successfully done: CABra_458_mmd.csv
# successfully done: CABra_45_mmd.csv
# successfully done: CABra_460_mmd.csv
# successfully done: CABra_461_mmd.csv
# successfully done: CABra_462_mmd.csv
# successfully done: CABra_463_mmd.csv
# successfully done: CABra_464_mmd.csv
# successfully done: CABra_465_mmd.csv
# successfully done: CABra_466_mmd.csv
# successfully done: CABra_467_mmd.csv
# successfully done: CABra_470_mmd.csv
# successfully done: CABra_471_mmd.csv
# successfully done: CABra_472_mmd.csv
# successfully done: CABra_473_mmd.csv
# successfully done: CABra_474_mmd.csv
# successfully done: CABra_475_mmd.csv
# successfully done: CABra_477_mmd.csv
# successfully done: CABra_479_mmd.csv
# successfully done: CABra_47_mmd.csv
# successfully done: CABra_480_mmd.csv
# successfully done: CABra_483_mmd.csv
# successfully done: CABra_486_mmd.csv
# successfully done: CABra_487_mmd.csv
# CABra_488_mmd.csv is ephemeral
# successfully done: CABra_489_mmd.csv
# successfully done: CABra_48_mmd.csv
# successfully done: CABra_490_mmd.csv
# successfully done: CABra_491_mmd.csv
# successfully done: CABra_493_mmd.csv
# successfully done: CABra_495_mmd.csv
# successfully done: CABra_496_mmd.csv
# CABra_499_mmd.csv is ephemeral
# successfully done: CABra_49_mmd.csv
# successfully done: CABra_4_mmd.csv
# successfully done: CABra_500_mmd.csv
# successfully done: CABra_501_mmd.csv
# successfully done: CABra_502_mmd.csv
# successfully done: CABra_503_mmd.csv
# successfully done: CABra_504_mmd.csv
# successfully done: CABra_506_mmd.csv
# successfully done: CABra_507_mmd.csv
# successfully done: CABra_509_mmd.csv
# successfully done: CABra_510_mmd.csv
# successfully done: CABra_511_mmd.csv
# successfully done: CABra_515_mmd.csv
# successfully done: CABra_520_mmd.csv
# successfully done: CABra_521_mmd.csv
# CABra_522_mmd.csv is ephemeral
# successfully done: CABra_526_mmd.csv
# successfully done: CABra_527_mmd.csv
# successfully done: CABra_528_mmd.csv
# successfully done: CABra_529_mmd.csv
# successfully done: CABra_530_mmd.csv
# successfully done: CABra_531_mmd.csv
# successfully done: CABra_532_mmd.csv
# successfully done: CABra_533_mmd.csv
# successfully done: CABra_535_mmd.csv
# successfully done: CABra_537_mmd.csv
# successfully done: CABra_538_mmd.csv
# successfully done: CABra_539_mmd.csv
# successfully done: CABra_540_mmd.csv
# successfully done: CABra_541_mmd.csv
# successfully done: CABra_543_mmd.csv
# successfully done: CABra_545_mmd.csv
# successfully done: CABra_546_mmd.csv
# successfully done: CABra_547_mmd.csv
# CABra_548_mmd.csv is ephemeral
# CABra_549_mmd.csv is ephemeral
# successfully done: CABra_552_mmd.csv
# successfully done: CABra_553_mmd.csv
# successfully done: CABra_554_mmd.csv
# successfully done: CABra_555_mmd.csv
# successfully done: CABra_556_mmd.csv
# successfully done: CABra_557_mmd.csv
# successfully done: CABra_558_mmd.csv
# successfully done: CABra_559_mmd.csv
# successfully done: CABra_55_mmd.csv
# successfully done: CABra_560_mmd.csv
# successfully done: CABra_561_mmd.csv
# successfully done: CABra_562_mmd.csv
# successfully done: CABra_563_mmd.csv
# successfully done: CABra_564_mmd.csv
# successfully done: CABra_565_mmd.csv
# successfully done: CABra_566_mmd.csv
# successfully done: CABra_567_mmd.csv
# successfully done: CABra_568_mmd.csv
# successfully done: CABra_569_mmd.csv
# successfully done: CABra_570_mmd.csv
# successfully done: CABra_572_mmd.csv
# successfully done: CABra_574_mmd.csv
# successfully done: CABra_575_mmd.csv
# successfully done: CABra_577_mmd.csv
# successfully done: CABra_578_mmd.csv
# successfully done: CABra_579_mmd.csv
# successfully done: CABra_580_mmd.csv
# successfully done: CABra_581_mmd.csv
# successfully done: CABra_582_mmd.csv
# successfully done: CABra_583_mmd.csv
# successfully done: CABra_584_mmd.csv
# successfully done: CABra_585_mmd.csv
# successfully done: CABra_587_mmd.csv
# successfully done: CABra_588_mmd.csv
# successfully done: CABra_589_mmd.csv
# successfully done: CABra_590_mmd.csv
# successfully done: CABra_591_mmd.csv
# successfully done: CABra_592_mmd.csv
# successfully done: CABra_593_mmd.csv
# successfully done: CABra_594_mmd.csv
# successfully done: CABra_595_mmd.csv
# successfully done: CABra_596_mmd.csv
# successfully done: CABra_597_mmd.csv
# successfully done: CABra_598_mmd.csv
# successfully done: CABra_599_mmd.csv
# successfully done: CABra_59_mmd.csv
# successfully done: CABra_5_mmd.csv
# successfully done: CABra_600_mmd.csv
# successfully done: CABra_601_mmd.csv
# successfully done: CABra_602_mmd.csv
# successfully done: CABra_603_mmd.csv
# successfully done: CABra_604_mmd.csv
# successfully done: CABra_605_mmd.csv
# successfully done: CABra_606_mmd.csv
# successfully done: CABra_607_mmd.csv
# successfully done: CABra_608_mmd.csv
# successfully done: CABra_609_mmd.csv
# successfully done: CABra_60_mmd.csv
# successfully done: CABra_611_mmd.csv
# successfully done: CABra_612_mmd.csv
# successfully done: CABra_613_mmd.csv
# successfully done: CABra_614_mmd.csv
# successfully done: CABra_616_mmd.csv
# successfully done: CABra_617_mmd.csv
# successfully done: CABra_618_mmd.csv
# successfully done: CABra_619_mmd.csv
# successfully done: CABra_61_mmd.csv
# successfully done: CABra_620_mmd.csv
# successfully done: CABra_621_mmd.csv
# successfully done: CABra_622_mmd.csv
# successfully done: CABra_623_mmd.csv
# successfully done: CABra_625_mmd.csv
# successfully done: CABra_627_mmd.csv
# successfully done: CABra_628_mmd.csv
# successfully done: CABra_631_mmd.csv
# successfully done: CABra_632_mmd.csv
# successfully done: CABra_633_mmd.csv
# successfully done: CABra_636_mmd.csv
# successfully done: CABra_638_mmd.csv
# successfully done: CABra_639_mmd.csv
# successfully done: CABra_640_mmd.csv
# successfully done: CABra_641_mmd.csv
# successfully done: CABra_644_mmd.csv
# successfully done: CABra_645_mmd.csv
# successfully done: CABra_646_mmd.csv
# successfully done: CABra_648_mmd.csv
# successfully done: CABra_649_mmd.csv
# successfully done: CABra_650_mmd.csv
# successfully done: CABra_651_mmd.csv
# successfully done: CABra_652_mmd.csv
# successfully done: CABra_654_mmd.csv
# successfully done: CABra_655_mmd.csv
# successfully done: CABra_656_mmd.csv
# successfully done: CABra_657_mmd.csv
# successfully done: CABra_658_mmd.csv
# successfully done: CABra_659_mmd.csv
# successfully done: CABra_660_mmd.csv
# successfully done: CABra_661_mmd.csv
# successfully done: CABra_662_mmd.csv
# successfully done: CABra_663_mmd.csv
# successfully done: CABra_665_mmd.csv
# successfully done: CABra_66_mmd.csv
# successfully done: CABra_670_mmd.csv
# CABra_674_mmd.csv is ephemeral
# successfully done: CABra_67_mmd.csv
# successfully done: CABra_680_mmd.csv
# successfully done: CABra_681_mmd.csv
# successfully done: CABra_683_mmd.csv
# successfully done: CABra_684_mmd.csv
# successfully done: CABra_685_mmd.csv
# CABra_688_mmd.csv is ephemeral
# CABra_689_mmd.csv is ephemeral
# successfully done: CABra_68_mmd.csv
# successfully done: CABra_692_mmd.csv
# successfully done: CABra_694_mmd.csv
# successfully done: CABra_696_mmd.csv
# successfully done: CABra_699_mmd.csv
# successfully done: CABra_6_mmd.csv
# successfully done: CABra_700_mmd.csv
# successfully done: CABra_704_mmd.csv
# successfully done: CABra_706_mmd.csv
# successfully done: CABra_707_mmd.csv
# successfully done: CABra_70_mmd.csv
# successfully done: CABra_710_mmd.csv
# successfully done: CABra_711_mmd.csv
# successfully done: CABra_712_mmd.csv
# successfully done: CABra_714_mmd.csv
# successfully done: CABra_715_mmd.csv
# CABra_71_mmd.csv is ephemeral
# CABra_720_mmd.csv is ephemeral
# successfully done: CABra_723_mmd.csv
# successfully done: CABra_725_mmd.csv
# successfully done: CABra_726_mmd.csv
# successfully done: CABra_727_mmd.csv
# CABra_728_mmd.csv is ephemeral
# CABra_729_mmd.csv is ephemeral
# successfully done: CABra_72_mmd.csv
# successfully done: CABra_731_mmd.csv
# successfully done: CABra_733_mmd.csv
# successfully done: CABra_734_mmd.csv
# successfully done: CABra_74_mmd.csv
# CABra_75_mmd.csv is ephemeral
# successfully done: CABra_76_mmd.csv
# successfully done: CABra_77_mmd.csv
# successfully done: CABra_7_mmd.csv
# successfully done: CABra_80_mmd.csv
# successfully done: CABra_81_mmd.csv
# successfully done: CABra_82_mmd.csv
# successfully done: CABra_85_mmd.csv
# successfully done: CABra_86_mmd.csv
# successfully done: CABra_87_mmd.csv
# successfully done: CABra_8_mmd.csv
# successfully done: CABra_90_mmd.csv
# successfully done: CABra_92_mmd.csv
# successfully done: CABra_93_mmd.csv
# successfully done: CABra_95_mmd.csv
# successfully done: CABra_96_mmd.csv
# successfully done: CABra_97_mmd.csv
# successfully done: CABra_98_mmd.csv
# successfully done: CABra_99_mmd.csv
# successfully done: CABra_9_mmd.csv
