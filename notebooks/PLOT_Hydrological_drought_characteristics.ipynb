# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
from matplotlib.patches import Polygon
from matplotlib.collections import PatchCollection
from cmcrameri import cm

# %%
#Import dataset - add your path to the dataset "All_attributes_drought.csv"
Col_att= ['duration-drought','deficit-drought','intensity-drought','Number of events-drought','id','latitude','longitude']
Attributes= pd.read_csv('All_attributes_drought.csv',engine='python', index_col=None, sep=',', usecols=Col_att)

# %% [markdown]
# ### Drought duration

# %%
#Set up base map
fig = plt.figure(figsize=(16,20))
ax = fig.add_subplot(111)
m = Basemap(projection='merc', llcrnrlat=-35, urcrnrlat=7,
                llcrnrlon=-77, urcrnrlon=-32, resolution='i')

# 1. Draw the map background
m.shadedrelief()
m.drawmapboundary(color="#ffffff")
m.drawmapscale(-43,-32,-33, 10, 1000, barstyle='fancy', 
               fillcolor1="#bdbdbd", fillcolor2="#f7f7f7", 
               linecolor="#969696", linewidth=0.6, fontsize=12)

# 2. Draw the regions - change the path to the shapefile "SNIRH_RegioesHidrograficas_2020"
m.readshapefile('SNIRH_RegioesHidrograficas_2020', 'regions', color="#ffffff", linewidth=1.5)
regions_info= m.readshapefile('SNIRH_RegioesHidrograficas_2020', 'regions', drawbounds=False)

patches = []
patches2 = []
patches3 = []
patches4 = []
patches5 = []
patches6 = []
patches7 = []
patches8 = []
patches9 = []
patches10 = []
patches11 = []
patches12 = []

# for info, shape in zip(m.biomas_info, m.biomas):
for info, shape in zip(m.regions_info, m.regions):
    if info['rhi_nm'] == 'URUGUAI':
        patches.append( Polygon(np.array(shape), True))
    if info['rhi_nm'] == 'SÃO FRANCISCO':
        patches2.append( Polygon(np.array(shape), True))
    if info['rhi_nm'] == 'PARANÁ':
        patches3.append( Polygon(np.array(shape), True))    
    if info['rhi_nm'] == 'TOCANTINS-ARAGUAIA':
        patches4.append( Polygon(np.array(shape), True)) 
    if info['rhi_nm'] == 'PARAGUAI':
        patches5.append( Polygon(np.array(shape), True)) 
    if info['rhi_nm'] == 'PARNAÍBA':
        patches6.append( Polygon(np.array(shape), True)) 
    if info['rhi_nm'] == 'ATLÂNTICO SUL':
        patches7.append( Polygon(np.array(shape), True)) 
    if info['rhi_nm'] == 'ATLÂNTICO NORDESTE ORIENTAL':
        patches8.append( Polygon(np.array(shape), True))
    if info['rhi_nm'] == 'ATLÂNTICO NORDESTE OCIDENTAL':
        patches9.append( Polygon(np.array(shape), True))
    if info['rhi_nm'] == 'AMAZÔNICA':
        patches10.append( Polygon(np.array(shape), True))
    if info['rhi_nm'] == 'ATLÂNTICO SUDESTE':
        patches11.append( Polygon(np.array(shape), True)) 
    if info['rhi_nm'] == 'ATLÂNTICO LESTE':
        patches12.append( Polygon(np.array(shape), True)) 
        
ax.add_collection(PatchCollection(patches, facecolor="#e0e0e0" , edgecolor='#ffffff', linewidths=1, zorder=1, alpha=0.9, label = "Uruguay"))
ax.add_collection(PatchCollection(patches2, facecolor="#e0e0e0" , edgecolor='#ffffff', linewidths=1, zorder=1, alpha=0.9, label = "São Francisco"))
ax.add_collection(PatchCollection(patches3, facecolor="#e0e0e0", edgecolor='#ffffff', linewidths=1, zorder=1, alpha=0.9, label = "Paraná"))
ax.add_collection(PatchCollection(patches4, facecolor="#e0e0e0", edgecolor='#ffffff', linewidths=1, zorder=1, alpha=0.9,label = "Tocantins/Araguaia"))
ax.add_collection(PatchCollection(patches5, facecolor="#e0e0e0" , edgecolor='#ffffff', linewidths=1, zorder=1, alpha=0.9, label="Paraguay"))
ax.add_collection(PatchCollection(patches6, facecolor="#e0e0e0" , edgecolor='#ffffff', linewidths=1, zorder=1, alpha=0.9, label="Parnaíba"))
ax.add_collection(PatchCollection(patches7, facecolor="#e0e0e0" , edgecolor='#ffffff', linewidths=1, zorder=1, alpha=0.9, label="South Atlantic"))
ax.add_collection(PatchCollection(patches8, facecolor="#e0e0e0" , edgecolor='#ffffff', linewidths=1, zorder=1, alpha=0.9, label="Western Northeast Atlantic"))
ax.add_collection(PatchCollection(patches9, facecolor="#e0e0e0" , edgecolor='#ffffff', linewidths=1, zorder=1, alpha=0.9, label="Eastern Northeast Atlantic"))
ax.add_collection(PatchCollection(patches10, facecolor="#e0e0e0" , edgecolor='#ffffff', linewidths=1, zorder=1, alpha=0.9, label="Amazon"))
ax.add_collection(PatchCollection(patches11, facecolor="#e0e0e0" , edgecolor='#ffffff', linewidths=1, zorder=1, alpha=0.9, label="Southeast Atlantic"))
ax.add_collection(PatchCollection(patches12, facecolor="#e0e0e0" , edgecolor='#ffffff', linewidths=1, zorder=1, alpha=0.9, label="East Atlantic"))

size=Attributes['duration-drought']

lat =Attributes['latitude'].values
lon = Attributes['longitude'].values
ids = Attributes['id']

scatter=m.scatter(lon, lat, latlon=True,
          c=size, s=100,
          cmap=cm.lajolla.reversed(), alpha=0.9, vmin=38, vmax=203)

node_bar=plt.colorbar(scatter, orientation='horizontal', shrink=0.4)

scatter.set_zorder(2)

#3.Save the figure - change the path to the folder where you want to save the figure

plt.savefig('Duration_drought.png', format = "png", dpi = 400)

plt.show
# Out:
# C:\Users\gqg5266\AppData\Local\Temp\ipykernel_26896\3400604867.py:38: MatplotlibDeprecationWarning: Passing the closed parameter of __init__() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   patches.append( Polygon(np.array(shape), True))
# C:\Users\gqg5266\AppData\Local\Temp\ipykernel_26896\3400604867.py:40: MatplotlibDeprecationWarning: Passing the closed parameter of __init__() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   patches2.append( Polygon(np.array(shape), True))
# C:\Users\gqg5266\AppData\Local\Temp\ipykernel_26896\3400604867.py:42: MatplotlibDeprecationWarning: Passing the closed parameter of __init__() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   patches3.append( Polygon(np.array(shape), True))
# C:\Users\gqg5266\AppData\Local\Temp\ipykernel_26896\3400604867.py:44: MatplotlibDeprecationWarning: Passing the closed parameter of __init__() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   patches4.append( Polygon(np.array(shape), True))
# C:\Users\gqg5266\AppData\Local\Temp\ipykernel_26896\3400604867.py:46: MatplotlibDeprecationWarning: Passing the closed parameter of __init__() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   patches5.append( Polygon(np.array(shape), True))
# C:\Users\gqg5266\AppData\Local\Temp\ipykernel_26896\3400604867.py:48: MatplotlibDeprecationWarning: Passing the closed parameter of __init__() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   patches6.append( Polygon(np.array(shape), True))
# C:\Users\gqg5266\AppData\Local\Temp\ipykernel_26896\3400604867.py:50: MatplotlibDeprecationWarning: Passing the closed parameter of __init__() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   patches7.append( Polygon(np.array(shape), True))
# C:\Users\gqg5266\AppData\Local\Temp\ipykernel_26896\3400604867.py:52: MatplotlibDeprecationWarning: Passing the closed parameter of __init__() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   patches8.append( Polygon(np.array(shape), True))
# C:\Users\gqg5266\AppData\Local\Temp\ipykernel_26896\3400604867.py:54: MatplotlibDeprecationWarning: Passing the closed parameter of __init__() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   patches9.append( Polygon(np.array(shape), True))
# C:\Users\gqg5266\AppData\Local\Temp\ipykernel_26896\3400604867.py:56: MatplotlibDeprecationWarning: Passing the closed parameter of __init__() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   patches10.append( Polygon(np.array(shape), True))
# C:\Users\gqg5266\AppData\Local\Temp\ipykernel_26896\3400604867.py:58: MatplotlibDeprecationWarning: Passing the closed parameter of __init__() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   patches11.append( Polygon(np.array(shape), True))
# C:\Users\gqg5266\AppData\Local\Temp\ipykernel_26896\3400604867.py:60: MatplotlibDeprecationWarning: Passing the closed parameter of __init__() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   patches12.append( Polygon(np.array(shape), True))
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Number of events

# %%
#Set up base map
fig = plt.figure(figsize=(16,20))
ax = fig.add_subplot(111)
m = Basemap(projection='merc', llcrnrlat=-35, urcrnrlat=7,
                llcrnrlon=-77, urcrnrlon=-32, resolution='i')

# 1. Draw the map background
m.shadedrelief()
m.drawmapboundary(color="#ffffff")
m.drawmapscale(-43,-32,-33, 10, 1000, barstyle='fancy', 
               fillcolor1="#bdbdbd", fillcolor2="#f7f7f7", 
               linecolor="#969696", linewidth=0.6, fontsize=12)

# 2. Draw the regions - change the path to the shapefile "SNIRH_RegioesHidrograficas_2020"
m.readshapefile('Path to /SNIRH_RegioesHidrograficas_2020', 'regions', color="#ffffff", linewidth=1.5)
regions_info= m.readshapefile('Path to /SNIRH_RegioesHidrograficas_2020', 'regions', drawbounds=False)

patches = []
patches2 = []
patches3 = []
patches4 = []
patches5 = []
patches6 = []
patches7 = []
patches8 = []
patches9 = []
patches10 = []
patches11 = []
patches12 = []

# for info, shape in zip(m.biomas_info, m.biomas):
for info, shape in zip(m.regions_info, m.regions):
    if info['rhi_nm'] == 'URUGUAI':
        patches.append( Polygon(np.array(shape), True))
    if info['rhi_nm'] == 'SÃO FRANCISCO':
        patches2.append( Polygon(np.array(shape), True))
    if info['rhi_nm'] == 'PARANÁ':
        patches3.append( Polygon(np.array(shape), True))    
    if info['rhi_nm'] == 'TOCANTINS-ARAGUAIA':
        patches4.append( Polygon(np.array(shape), True)) 
    if info['rhi_nm'] == 'PARAGUAI':
        patches5.append( Polygon(np.array(shape), True)) 
    if info['rhi_nm'] == 'PARNAÍBA':
        patches6.append( Polygon(np.array(shape), True)) 
    if info['rhi_nm'] == 'ATLÂNTICO SUL':
        patches7.append( Polygon(np.array(shape), True)) 
    if info['rhi_nm'] == 'ATLÂNTICO NORDESTE ORIENTAL':
        patches8.append( Polygon(np.array(shape), True))
    if info['rhi_nm'] == 'ATLÂNTICO NORDESTE OCIDENTAL':
        patches9.append( Polygon(np.array(shape), True))
    if info['rhi_nm'] == 'AMAZÔNICA':
        patches10.append( Polygon(np.array(shape), True))
    if info['rhi_nm'] == 'ATLÂNTICO SUDESTE':
        patches11.append( Polygon(np.array(shape), True)) 
    if info['rhi_nm'] == 'ATLÂNTICO LESTE':
        patches12.append( Polygon(np.array(shape), True)) 
        
ax.add_collection(PatchCollection(patches, facecolor="#e0e0e0" , edgecolor='#ffffff', linewidths=1, zorder=1, alpha=0.9, label = "Uruguay"))
ax.add_collection(PatchCollection(patches2, facecolor="#e0e0e0" , edgecolor='#ffffff', linewidths=1, zorder=1, alpha=0.9, label = "São Francisco"))
ax.add_collection(PatchCollection(patches3, facecolor="#e0e0e0", edgecolor='#ffffff', linewidths=1, zorder=1, alpha=0.9, label = "Paraná"))
ax.add_collection(PatchCollection(patches4, facecolor="#e0e0e0", edgecolor='#ffffff', linewidths=1, zorder=1, alpha=0.9,label = "Tocantins/Araguaia"))
ax.add_collection(PatchCollection(patches5, facecolor="#e0e0e0" , edgecolor='#ffffff', linewidths=1, zorder=1, alpha=0.9, label="Paraguay"))
ax.add_collection(PatchCollection(patches6, facecolor="#e0e0e0" , edgecolor='#ffffff', linewidths=1, zorder=1, alpha=0.9, label="Parnaíba"))
ax.add_collection(PatchCollection(patches7, facecolor="#e0e0e0" , edgecolor='#ffffff', linewidths=1, zorder=1, alpha=0.9, label="South Atlantic"))
ax.add_collection(PatchCollection(patches8, facecolor="#e0e0e0" , edgecolor='#ffffff', linewidths=1, zorder=1, alpha=0.9, label="Western Northeast Atlantic"))
ax.add_collection(PatchCollection(patches9, facecolor="#e0e0e0" , edgecolor='#ffffff', linewidths=1, zorder=1, alpha=0.9, label="Eastern Northeast Atlantic"))
ax.add_collection(PatchCollection(patches10, facecolor="#e0e0e0" , edgecolor='#ffffff', linewidths=1, zorder=1, alpha=0.9, label="Amazon"))
ax.add_collection(PatchCollection(patches11, facecolor="#e0e0e0" , edgecolor='#ffffff', linewidths=1, zorder=1, alpha=0.9, label="Southeast Atlantic"))
ax.add_collection(PatchCollection(patches12, facecolor="#e0e0e0" , edgecolor='#ffffff', linewidths=1, zorder=1, alpha=0.9, label="East Atlantic"))

size=Attributes['Number of events-drought']

lat =Attributes['latitude'].values
lon = Attributes['longitude'].values
ids = Attributes['id']

scatter=m.scatter(lon, lat, latlon=True,
          c=size, s=100,
          cmap=cm.lajolla.reversed(), alpha=0.9, vmin=7, vmax=30)

node_bar=plt.colorbar(scatter, orientation='horizontal', shrink=0.4)

scatter.set_zorder(2)

#3.Save the figure - change the path to the folder where you want to save the figure
plt.savefig('/Nevents_drought.png', format = "png", dpi = 400)

plt.show
# Out:
# C:\Users\gqg5266\AppData\Local\Temp\ipykernel_26896\179365030.py:33: MatplotlibDeprecationWarning: Passing the closed parameter of __init__() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   patches.append( Polygon(np.array(shape), True))
# C:\Users\gqg5266\AppData\Local\Temp\ipykernel_26896\179365030.py:35: MatplotlibDeprecationWarning: Passing the closed parameter of __init__() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   patches2.append( Polygon(np.array(shape), True))
# C:\Users\gqg5266\AppData\Local\Temp\ipykernel_26896\179365030.py:37: MatplotlibDeprecationWarning: Passing the closed parameter of __init__() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   patches3.append( Polygon(np.array(shape), True))
# C:\Users\gqg5266\AppData\Local\Temp\ipykernel_26896\179365030.py:39: MatplotlibDeprecationWarning: Passing the closed parameter of __init__() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   patches4.append( Polygon(np.array(shape), True))
# C:\Users\gqg5266\AppData\Local\Temp\ipykernel_26896\179365030.py:41: MatplotlibDeprecationWarning: Passing the closed parameter of __init__() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   patches5.append( Polygon(np.array(shape), True))
# C:\Users\gqg5266\AppData\Local\Temp\ipykernel_26896\179365030.py:43: MatplotlibDeprecationWarning: Passing the closed parameter of __init__() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   patches6.append( Polygon(np.array(shape), True))
# C:\Users\gqg5266\AppData\Local\Temp\ipykernel_26896\179365030.py:45: MatplotlibDeprecationWarning: Passing the closed parameter of __init__() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   patches7.append( Polygon(np.array(shape), True))
# C:\Users\gqg5266\AppData\Local\Temp\ipykernel_26896\179365030.py:47: MatplotlibDeprecationWarning: Passing the closed parameter of __init__() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   patches8.append( Polygon(np.array(shape), True))
# C:\Users\gqg5266\AppData\Local\Temp\ipykernel_26896\179365030.py:49: MatplotlibDeprecationWarning: Passing the closed parameter of __init__() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   patches9.append( Polygon(np.array(shape), True))
# C:\Users\gqg5266\AppData\Local\Temp\ipykernel_26896\179365030.py:51: MatplotlibDeprecationWarning: Passing the closed parameter of __init__() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   patches10.append( Polygon(np.array(shape), True))
# C:\Users\gqg5266\AppData\Local\Temp\ipykernel_26896\179365030.py:53: MatplotlibDeprecationWarning: Passing the closed parameter of __init__() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   patches11.append( Polygon(np.array(shape), True))
# C:\Users\gqg5266\AppData\Local\Temp\ipykernel_26896\179365030.py:55: MatplotlibDeprecationWarning: Passing the closed parameter of __init__() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   patches12.append( Polygon(np.array(shape), True))
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Drought Deficit

# %%
#Set up base map
fig = plt.figure(figsize=(16,20))
ax = fig.add_subplot(111)
m = Basemap(projection='merc', llcrnrlat=-35, urcrnrlat=7,
                llcrnrlon=-77, urcrnrlon=-32, resolution='i')

# 1. Draw the map background
m.shadedrelief()
m.drawmapboundary(color="#ffffff")
m.drawmapscale(-43,-32,-33, 10, 1000, barstyle='fancy', 
               fillcolor1="#bdbdbd", fillcolor2="#f7f7f7", 
               linecolor="#969696", linewidth=0.6, fontsize=12)

# 2. Draw the regions - change the path to the shapefile "SNIRH_RegioesHidrograficas_2020"
m.readshapefile('Path to /SNIRH_RegioesHidrograficas_2020', 'regions', color="#ffffff", linewidth=1.5)
regions_info= m.readshapefile('Path to /SNIRH_RegioesHidrograficas_2020', 'regions', drawbounds=False)

patches = []
patches2 = []
patches3 = []
patches4 = []
patches5 = []
patches6 = []
patches7 = []
patches8 = []
patches9 = []
patches10 = []
patches11 = []
patches12 = []

# for info, shape in zip(m.biomas_info, m.biomas):
for info, shape in zip(m.regions_info, m.regions):
    if info['rhi_nm'] == 'URUGUAI':
        patches.append( Polygon(np.array(shape), True))
    if info['rhi_nm'] == 'SÃO FRANCISCO':
        patches2.append( Polygon(np.array(shape), True))
    if info['rhi_nm'] == 'PARANÁ':
        patches3.append( Polygon(np.array(shape), True))    
    if info['rhi_nm'] == 'TOCANTINS-ARAGUAIA':
        patches4.append( Polygon(np.array(shape), True)) 
    if info['rhi_nm'] == 'PARAGUAI':
        patches5.append( Polygon(np.array(shape), True)) 
    if info['rhi_nm'] == 'PARNAÍBA':
        patches6.append( Polygon(np.array(shape), True)) 
    if info['rhi_nm'] == 'ATLÂNTICO SUL':
        patches7.append( Polygon(np.array(shape), True)) 
    if info['rhi_nm'] == 'ATLÂNTICO NORDESTE ORIENTAL':
        patches8.append( Polygon(np.array(shape), True))
    if info['rhi_nm'] == 'ATLÂNTICO NORDESTE OCIDENTAL':
        patches9.append( Polygon(np.array(shape), True))
    if info['rhi_nm'] == 'AMAZÔNICA':
        patches10.append( Polygon(np.array(shape), True))
    if info['rhi_nm'] == 'ATLÂNTICO SUDESTE':
        patches11.append( Polygon(np.array(shape), True)) 
    if info['rhi_nm'] == 'ATLÂNTICO LESTE':
        patches12.append( Polygon(np.array(shape), True)) 
        
ax.add_collection(PatchCollection(patches, facecolor="#e0e0e0" , edgecolor='#ffffff', linewidths=1, zorder=1, alpha=0.9, label = "Uruguay"))
ax.add_collection(PatchCollection(patches2, facecolor="#e0e0e0" , edgecolor='#ffffff', linewidths=1, zorder=1, alpha=0.9, label = "São Francisco"))
ax.add_collection(PatchCollection(patches3, facecolor="#e0e0e0", edgecolor='#ffffff', linewidths=1, zorder=1, alpha=0.9, label = "Paraná"))
ax.add_collection(PatchCollection(patches4, facecolor="#e0e0e0", edgecolor='#ffffff', linewidths=1, zorder=1, alpha=0.9,label = "Tocantins/Araguaia"))
ax.add_collection(PatchCollection(patches5, facecolor="#e0e0e0" , edgecolor='#ffffff', linewidths=1, zorder=1, alpha=0.9, label="Paraguay"))
ax.add_collection(PatchCollection(patches6, facecolor="#e0e0e0" , edgecolor='#ffffff', linewidths=1, zorder=1, alpha=0.9, label="Parnaíba"))
ax.add_collection(PatchCollection(patches7, facecolor="#e0e0e0" , edgecolor='#ffffff', linewidths=1, zorder=1, alpha=0.9, label="South Atlantic"))
ax.add_collection(PatchCollection(patches8, facecolor="#e0e0e0" , edgecolor='#ffffff', linewidths=1, zorder=1, alpha=0.9, label="Western Northeast Atlantic"))
ax.add_collection(PatchCollection(patches9, facecolor="#e0e0e0" , edgecolor='#ffffff', linewidths=1, zorder=1, alpha=0.9, label="Eastern Northeast Atlantic"))
ax.add_collection(PatchCollection(patches10, facecolor="#e0e0e0" , edgecolor='#ffffff', linewidths=1, zorder=1, alpha=0.9, label="Amazon"))
ax.add_collection(PatchCollection(patches11, facecolor="#e0e0e0" , edgecolor='#ffffff', linewidths=1, zorder=1, alpha=0.9, label="Southeast Atlantic"))
ax.add_collection(PatchCollection(patches12, facecolor="#e0e0e0" , edgecolor='#ffffff', linewidths=1, zorder=1, alpha=0.9, label="East Atlantic"))

size=Attributes['deficit-drought']

lat =Attributes['latitude'].values
lon = Attributes['longitude'].values
ids = Attributes['id']

scatter=m.scatter(lon, lat, latlon=True,
          c=size, s=100,
          cmap=cm.lajolla.reversed(), alpha=0.9)

node_bar=plt.colorbar(scatter, orientation='horizontal', shrink=0.4)

scatter.set_zorder(2)

#3.Save the figure - change the path to the folder where you want to save the figure
plt.savefig('/Deficit-drought.png', format = "png", dpi = 400)

plt.show
# Out:
# C:\Users\gqg5266\AppData\Local\Temp\ipykernel_26896\1913455162.py:33: MatplotlibDeprecationWarning: Passing the closed parameter of __init__() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   patches.append( Polygon(np.array(shape), True))
# C:\Users\gqg5266\AppData\Local\Temp\ipykernel_26896\1913455162.py:35: MatplotlibDeprecationWarning: Passing the closed parameter of __init__() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   patches2.append( Polygon(np.array(shape), True))
# C:\Users\gqg5266\AppData\Local\Temp\ipykernel_26896\1913455162.py:37: MatplotlibDeprecationWarning: Passing the closed parameter of __init__() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   patches3.append( Polygon(np.array(shape), True))
# C:\Users\gqg5266\AppData\Local\Temp\ipykernel_26896\1913455162.py:39: MatplotlibDeprecationWarning: Passing the closed parameter of __init__() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   patches4.append( Polygon(np.array(shape), True))
# C:\Users\gqg5266\AppData\Local\Temp\ipykernel_26896\1913455162.py:41: MatplotlibDeprecationWarning: Passing the closed parameter of __init__() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   patches5.append( Polygon(np.array(shape), True))
# C:\Users\gqg5266\AppData\Local\Temp\ipykernel_26896\1913455162.py:43: MatplotlibDeprecationWarning: Passing the closed parameter of __init__() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   patches6.append( Polygon(np.array(shape), True))
# C:\Users\gqg5266\AppData\Local\Temp\ipykernel_26896\1913455162.py:45: MatplotlibDeprecationWarning: Passing the closed parameter of __init__() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   patches7.append( Polygon(np.array(shape), True))
# C:\Users\gqg5266\AppData\Local\Temp\ipykernel_26896\1913455162.py:47: MatplotlibDeprecationWarning: Passing the closed parameter of __init__() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   patches8.append( Polygon(np.array(shape), True))
# C:\Users\gqg5266\AppData\Local\Temp\ipykernel_26896\1913455162.py:49: MatplotlibDeprecationWarning: Passing the closed parameter of __init__() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   patches9.append( Polygon(np.array(shape), True))
# C:\Users\gqg5266\AppData\Local\Temp\ipykernel_26896\1913455162.py:51: MatplotlibDeprecationWarning: Passing the closed parameter of __init__() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   patches10.append( Polygon(np.array(shape), True))
# C:\Users\gqg5266\AppData\Local\Temp\ipykernel_26896\1913455162.py:53: MatplotlibDeprecationWarning: Passing the closed parameter of __init__() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   patches11.append( Polygon(np.array(shape), True))
# C:\Users\gqg5266\AppData\Local\Temp\ipykernel_26896\1913455162.py:55: MatplotlibDeprecationWarning: Passing the closed parameter of __init__() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   patches12.append( Polygon(np.array(shape), True))
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Drought Intensity

# %%
#Set up base map
fig = plt.figure(figsize=(16,20))
ax = fig.add_subplot(111)
m = Basemap(projection='merc', llcrnrlat=-35, urcrnrlat=7,
                llcrnrlon=-77, urcrnrlon=-32, resolution='i')

# 1. Draw the map background
m.shadedrelief()
m.drawmapboundary(color="#ffffff")
m.drawmapscale(-43,-32,-33, 10, 1000, barstyle='fancy', 
               fillcolor1="#bdbdbd", fillcolor2="#f7f7f7", 
               linecolor="#969696", linewidth=0.6, fontsize=12)

# 2. Draw the regions - change the path to the shapefile "SNIRH_RegioesHidrograficas_2020"
m.readshapefile('Path to /SNIRH_RegioesHidrograficas_2020', 'regions', color="#ffffff", linewidth=1.5)
regions_info= m.readshapefile('Path to /SNIRH_RegioesHidrograficas_2020', 'regions', drawbounds=False)

patches = []
patches2 = []
patches3 = []
patches4 = []
patches5 = []
patches6 = []
patches7 = []
patches8 = []
patches9 = []
patches10 = []
patches11 = []
patches12 = []

# for info, shape in zip(m.biomas_info, m.biomas):
for info, shape in zip(m.regions_info, m.regions):
    if info['rhi_nm'] == 'URUGUAI':
        patches.append( Polygon(np.array(shape), True))
    if info['rhi_nm'] == 'SÃO FRANCISCO':
        patches2.append( Polygon(np.array(shape), True))
    if info['rhi_nm'] == 'PARANÁ':
        patches3.append( Polygon(np.array(shape), True))    
    if info['rhi_nm'] == 'TOCANTINS-ARAGUAIA':
        patches4.append( Polygon(np.array(shape), True)) 
    if info['rhi_nm'] == 'PARAGUAI':
        patches5.append( Polygon(np.array(shape), True)) 
    if info['rhi_nm'] == 'PARNAÍBA':
        patches6.append( Polygon(np.array(shape), True)) 
    if info['rhi_nm'] == 'ATLÂNTICO SUL':
        patches7.append( Polygon(np.array(shape), True)) 
    if info['rhi_nm'] == 'ATLÂNTICO NORDESTE ORIENTAL':
        patches8.append( Polygon(np.array(shape), True))
    if info['rhi_nm'] == 'ATLÂNTICO NORDESTE OCIDENTAL':
        patches9.append( Polygon(np.array(shape), True))
    if info['rhi_nm'] == 'AMAZÔNICA':
        patches10.append( Polygon(np.array(shape), True))
    if info['rhi_nm'] == 'ATLÂNTICO SUDESTE':
        patches11.append( Polygon(np.array(shape), True)) 
    if info['rhi_nm'] == 'ATLÂNTICO LESTE':
        patches12.append( Polygon(np.array(shape), True)) 
        
ax.add_collection(PatchCollection(patches, facecolor="#e0e0e0" , edgecolor='#ffffff', linewidths=1, zorder=1, alpha=0.9, label = "Uruguay"))
ax.add_collection(PatchCollection(patches2, facecolor="#e0e0e0" , edgecolor='#ffffff', linewidths=1, zorder=1, alpha=0.9, label = "São Francisco"))
ax.add_collection(PatchCollection(patches3, facecolor="#e0e0e0", edgecolor='#ffffff', linewidths=1, zorder=1, alpha=0.9, label = "Paraná"))
ax.add_collection(PatchCollection(patches4, facecolor="#e0e0e0", edgecolor='#ffffff', linewidths=1, zorder=1, alpha=0.9,label = "Tocantins/Araguaia"))
ax.add_collection(PatchCollection(patches5, facecolor="#e0e0e0" , edgecolor='#ffffff', linewidths=1, zorder=1, alpha=0.9, label="Paraguay"))
ax.add_collection(PatchCollection(patches6, facecolor="#e0e0e0" , edgecolor='#ffffff', linewidths=1, zorder=1, alpha=0.9, label="Parnaíba"))
ax.add_collection(PatchCollection(patches7, facecolor="#e0e0e0" , edgecolor='#ffffff', linewidths=1, zorder=1, alpha=0.9, label="South Atlantic"))
ax.add_collection(PatchCollection(patches8, facecolor="#e0e0e0" , edgecolor='#ffffff', linewidths=1, zorder=1, alpha=0.9, label="Western Northeast Atlantic"))
ax.add_collection(PatchCollection(patches9, facecolor="#e0e0e0" , edgecolor='#ffffff', linewidths=1, zorder=1, alpha=0.9, label="Eastern Northeast Atlantic"))
ax.add_collection(PatchCollection(patches10, facecolor="#e0e0e0" , edgecolor='#ffffff', linewidths=1, zorder=1, alpha=0.9, label="Amazon"))
ax.add_collection(PatchCollection(patches11, facecolor="#e0e0e0" , edgecolor='#ffffff', linewidths=1, zorder=1, alpha=0.9, label="Southeast Atlantic"))
ax.add_collection(PatchCollection(patches12, facecolor="#e0e0e0" , edgecolor='#ffffff', linewidths=1, zorder=1, alpha=0.9, label="East Atlantic"))

size=Attributes['intensity-drought']

lat =Attributes['latitude'].values
lon = Attributes['longitude'].values
ids = Attributes['id']

scatter=m.scatter(lon, lat, latlon=True,
          c=size, s=100,
          cmap=cm.lajolla.reversed(), alpha=0.9)

node_bar=plt.colorbar(scatter, orientation='horizontal', shrink=0.4)

scatter.set_zorder(2)

#3.Save the figure - change the path to the folder where you want to save the figure
plt.savefig('Intensity-drought.png', format = "png", dpi = 400)

plt.show
# Out:
# C:\Users\gqg5266\AppData\Local\Temp\ipykernel_26896\2165140295.py:33: MatplotlibDeprecationWarning: Passing the closed parameter of __init__() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   patches.append( Polygon(np.array(shape), True))
# C:\Users\gqg5266\AppData\Local\Temp\ipykernel_26896\2165140295.py:35: MatplotlibDeprecationWarning: Passing the closed parameter of __init__() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   patches2.append( Polygon(np.array(shape), True))
# C:\Users\gqg5266\AppData\Local\Temp\ipykernel_26896\2165140295.py:37: MatplotlibDeprecationWarning: Passing the closed parameter of __init__() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   patches3.append( Polygon(np.array(shape), True))
# C:\Users\gqg5266\AppData\Local\Temp\ipykernel_26896\2165140295.py:39: MatplotlibDeprecationWarning: Passing the closed parameter of __init__() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   patches4.append( Polygon(np.array(shape), True))
# C:\Users\gqg5266\AppData\Local\Temp\ipykernel_26896\2165140295.py:41: MatplotlibDeprecationWarning: Passing the closed parameter of __init__() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   patches5.append( Polygon(np.array(shape), True))
# C:\Users\gqg5266\AppData\Local\Temp\ipykernel_26896\2165140295.py:43: MatplotlibDeprecationWarning: Passing the closed parameter of __init__() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   patches6.append( Polygon(np.array(shape), True))
# C:\Users\gqg5266\AppData\Local\Temp\ipykernel_26896\2165140295.py:45: MatplotlibDeprecationWarning: Passing the closed parameter of __init__() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   patches7.append( Polygon(np.array(shape), True))
# C:\Users\gqg5266\AppData\Local\Temp\ipykernel_26896\2165140295.py:47: MatplotlibDeprecationWarning: Passing the closed parameter of __init__() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   patches8.append( Polygon(np.array(shape), True))
# C:\Users\gqg5266\AppData\Local\Temp\ipykernel_26896\2165140295.py:49: MatplotlibDeprecationWarning: Passing the closed parameter of __init__() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   patches9.append( Polygon(np.array(shape), True))
# C:\Users\gqg5266\AppData\Local\Temp\ipykernel_26896\2165140295.py:51: MatplotlibDeprecationWarning: Passing the closed parameter of __init__() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   patches10.append( Polygon(np.array(shape), True))
# C:\Users\gqg5266\AppData\Local\Temp\ipykernel_26896\2165140295.py:53: MatplotlibDeprecationWarning: Passing the closed parameter of __init__() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   patches11.append( Polygon(np.array(shape), True))
# C:\Users\gqg5266\AppData\Local\Temp\ipykernel_26896\2165140295.py:55: MatplotlibDeprecationWarning: Passing the closed parameter of __init__() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   patches12.append( Polygon(np.array(shape), True))
# <function matplotlib.pyplot.show(close=None, block=None)>
